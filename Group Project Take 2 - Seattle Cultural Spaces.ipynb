# %%
import pandas as pd

# %%
import os

# %%
culturalspacesexcel='https://github.com/elstephens1216/PUBPOL542/blob/main/SeattleCulturalSpaceInventory.xlsx?raw=true'

# %%
culturalspaces=pd.read_excel(culturalspacesexcel)

# %%
culturalspaces
# Out:
#                                                  Name           Phone  \
# 0                                          Tmrw Party             NaN
# 1                            Urban Wilderness Project             NaN
# 2                                     Bootstrap Music             NaN
# 3                                     Temple of Cairo             NaN
# 4                               Dynamic Sound Service             NaN
# ...                                               ...             ...
# 1209                Seattle Center EMP and Sky Church  (206) 770-2700
# 1210                                 The Project Room  (206) 499-9641
# 1211                           Seattle Pottery Supply             NaN
# 1212                           South Side Dance Force  (253) 639-5829
# 1213  University of Washington Jacob Lawrence Gallery             NaN
#
#                              URL  Square Feet Total              Neighborhood  \
# ...

# %%
import re

# %%
WhenYouFind='\\s+|\\d+|\\[|\\]'
replaceWith=''

# %% [markdown]
# Renaming columns:

# %%
culturalspaces.columns.str.replace(WhenYouFind,replaceWith,regex=True).str.lower()
# Out:
# Index(['name', 'phone', 'url', 'squarefeettotal', 'neighborhood',
#        'organizationtype', 'dominantdiscipline', 'yearofoccupation',
#        'rentvsown', 'ageofcurrentbuilding', 'lengthoflease(date)',
#        'yearorganizationfounded', 'numberofpastfacilities',
#        'stagesandtheaters', 'stage&theaterseats', 'galleryspace',
#        'gallerysquarefeet', 'adacompliant', 'availableparking',
#        'streetpresence', 'rentalspace', 'alcoholsales', 'organizationmission',
#        'fundedbya&c', 'fundedbyculture',
#        'stabilityindex(=verystable,=veryuncertain)',
#        'controlindex(=veryincontrol,=veryoutofcontrol)',
#        'constituencyover%onerace', 'specificdemographicsandcommunity',
#        'organizationleadership', 'organizationartists', 'closeddate',
#        'closed?', 'address', 'location', 'latitude', 'longitude'],
#       dtype='object')

# %%
culturalspaces.columns[1::].str.replace(WhenYouFind,replaceWith,regex=True).str.lower()
# Out:
# Index(['phone', 'url', 'squarefeettotal', 'neighborhood', 'organizationtype',
#        'dominantdiscipline', 'yearofoccupation', 'rentvsown',
#        'ageofcurrentbuilding', 'lengthoflease(date)',
#        'yearorganizationfounded', 'numberofpastfacilities',
#        'stagesandtheaters', 'stage&theaterseats', 'galleryspace',
#        'gallerysquarefeet', 'adacompliant', 'availableparking',
#        'streetpresence', 'rentalspace', 'alcoholsales', 'organizationmission',
#        'fundedbya&c', 'fundedbyculture',
#        'stabilityindex(=verystable,=veryuncertain)',
#        'controlindex(=veryincontrol,=veryoutofcontrol)',
#        'constituencyover%onerace', 'specificdemographicsandcommunity',
#        'organizationleadership', 'organizationartists', 'closeddate',
#        'closed?', 'address', 'location', 'latitude', 'longitude'],
#       dtype='object')

# %%
RenamedColumns=culturalspaces.columns[1::].str.replace(WhenYouFind,replaceWith,regex=True).str.lower()
RenamedColumns
# Out:
# Index(['phone', 'url', 'squarefeettotal', 'neighborhood', 'organizationtype',
#        'dominantdiscipline', 'yearofoccupation', 'rentvsown',
#        'ageofcurrentbuilding', 'lengthoflease(date)',
#        'yearorganizationfounded', 'numberofpastfacilities',
#        'stagesandtheaters', 'stage&theaterseats', 'galleryspace',
#        'gallerysquarefeet', 'adacompliant', 'availableparking',
#        'streetpresence', 'rentalspace', 'alcoholsales', 'organizationmission',
#        'fundedbya&c', 'fundedbyculture',
#        'stabilityindex(=verystable,=veryuncertain)',
#        'controlindex(=veryincontrol,=veryoutofcontrol)',
#        'constituencyover%onerace', 'specificdemographicsandcommunity',
#        'organizationleadership', 'organizationartists', 'closeddate',
#        'closed?', 'address', 'location', 'latitude', 'longitude'],
#       dtype='object')

# %%
changes=dict(zip(culturalspaces.iloc[:,1::].columns,RenamedColumns))
changes
# Out:
# {'Phone': 'phone',
#  'URL': 'url',
#  'Square Feet Total': 'squarefeettotal',
#  'Neighborhood': 'neighborhood',
#  'Organization Type': 'organizationtype',
#  'Dominant Discipline': 'dominantdiscipline',
#  'Year of Occupation': 'yearofoccupation',
#  'Rent vs Own': 'rentvsown',
#  'Age of Current Building': 'ageofcurrentbuilding',
#  'Length of Lease (Date)': 'lengthoflease(date)',
#  ' Year Organization Founded': 'yearorganizationfounded',
#  'Number of Past Facilities': 'numberofpastfacilities',
#  'Stages and Theaters': 'stagesandtheaters',
#  'Stage & Theater Seats ': 'stage&theaterseats',
#  'Gallery Space': 'galleryspace',
#  'Gallery Square Feet': 'gallerysquarefeet',
#  'ADA Compliant': 'adacompliant',
#  'Available Parking': 'availableparking',
#  'Street Presence': 'streetpresence',
#  'Rental Space ': 'rentalspace',
#  'Alcohol Sales': 'alcoholsales',
#  'Organization Mission': 'organizationmission',
#  'Funded by A&C': 'fundedbya&c',
# ...

# %%
culturalspaces.rename(columns=changes,inplace=True)

# %%
culturalspaces
# Out:
#                                                  Name           phone  \
# 0                                          Tmrw Party             NaN
# 1                            Urban Wilderness Project             NaN
# 2                                     Bootstrap Music             NaN
# 3                                     Temple of Cairo             NaN
# 4                               Dynamic Sound Service             NaN
# ...                                               ...             ...
# 1209                Seattle Center EMP and Sky Church  (206) 770-2700
# 1210                                 The Project Room  (206) 499-9641
# 1211                           Seattle Pottery Supply             NaN
# 1212                           South Side Dance Force  (253) 639-5829
# 1213  University of Washington Jacob Lawrence Gallery             NaN
#
#                              url  squarefeettotal              neighborhood  \
# ...

# %% [markdown]
# # Deleting some unnecessary columns

# %%
del culturalspaces['phone']

# %%
culturalspaces
# Out:
#                                                  Name  \
# 0                                          Tmrw Party
# 1                            Urban Wilderness Project
# 2                                     Bootstrap Music
# 3                                     Temple of Cairo
# 4                               Dynamic Sound Service
# ...                                               ...
# 1209                Seattle Center EMP and Sky Church
# 1210                                 The Project Room
# 1211                           Seattle Pottery Supply
# 1212                           South Side Dance Force
# 1213  University of Washington Jacob Lawrence Gallery
#
#                              url  squarefeettotal              neighborhood  \
# 0                            NaN              NaN                       NaN
# 1                            NaN              NaN                       NaN
# 2                            NaN              NaN                       NaN
# ...

# %%
del culturalspaces['url']
del culturalspaces['squarefeettotal']
del culturalspaces['rentvsown']
del culturalspaces['organizationtype']

# %%
del culturalspaces['ageofcurrentbuilding']
del culturalspaces['lengthoflease(date)']
del culturalspaces['yearorganizationfounded']

# %%
del culturalspaces['numberofpastfacilities']
del culturalspaces['stagesandtheaters']
del culturalspaces['stage&theaterseats']
del culturalspaces['galleryspace']

# %%
del culturalspaces['gallerysquarefeet']
del culturalspaces['adacompliant']
del culturalspaces['availableparking']
del culturalspaces['streetpresence']
del culturalspaces['rentalspace']

# %%
del culturalspaces['organizationmission']
del culturalspaces['alcoholsales']
del culturalspaces['fundedbya&c']
del culturalspaces['fundedbyculture']

# %%
del culturalspaces['stabilityindex(=verystable,=veryuncertain)']
del culturalspaces['controlindex(=veryincontrol,=veryoutofcontrol)']
del culturalspaces['constituencyover%onerace']

# %%
del culturalspaces['specificdemographicsandcommunity']
del culturalspaces['organizationleadership']
del culturalspaces['organizationartists']
del culturalspaces['location']
del culturalspaces['latitude']
del culturalspaces['longitude']

# %%
culturalspaces
# Out:
#                                                  Name  \
# 0                                          Tmrw Party
# 1                            Urban Wilderness Project
# 2                                     Bootstrap Music
# 3                                     Temple of Cairo
# 4                               Dynamic Sound Service
# ...                                               ...
# 1209                Seattle Center EMP and Sky Church
# 1210                                 The Project Room
# 1211                           Seattle Pottery Supply
# 1212                           South Side Dance Force
# 1213  University of Washington Jacob Lawrence Gallery
#
#                   neighborhood                   dominantdiscipline  \
# 0                          NaN                            Multi-use
# 1                          NaN                            Multi-use
# 2                          NaN                              Studios
# ...

# %% [markdown]
# Testing splitting up address column

# %%
CStest=culturalspaces.copy()

# %%
CStest
# Out:
#                                                  Name  \
# 0                                          Tmrw Party
# 1                            Urban Wilderness Project
# 2                                     Bootstrap Music
# 3                                     Temple of Cairo
# 4                               Dynamic Sound Service
# ...                                               ...
# 1209                Seattle Center EMP and Sky Church
# 1210                                 The Project Room
# 1211                           Seattle Pottery Supply
# 1212                           South Side Dance Force
# 1213  University of Washington Jacob Lawrence Gallery
#
#                   neighborhood                   dominantdiscipline  \
# 0                          NaN                            Multi-use
# 1                          NaN                            Multi-use
# 2                          NaN                              Studios
# ...

# %%
CStest['zipcode'] = CStest['address'].str.extract(r'(\d{5}\-?)')

# %%
CStest
# Out:
#                                                  Name  \
# 0                                          Tmrw Party
# 1                            Urban Wilderness Project
# 2                                     Bootstrap Music
# 3                                     Temple of Cairo
# 4                               Dynamic Sound Service
# ...                                               ...
# 1209                Seattle Center EMP and Sky Church
# 1210                                 The Project Room
# 1211                           Seattle Pottery Supply
# 1212                           South Side Dance Force
# 1213  University of Washington Jacob Lawrence Gallery
#
#                   neighborhood                   dominantdiscipline  \
# 0                          NaN                            Multi-use
# 1                          NaN                            Multi-use
# 2                          NaN                              Studios
# ...

# %% [markdown]
# Actually removing spaces:

# %%
culturalspaces['zipcode'] = culturalspaces['address'].str.extract(r'(\d{5}\-?)')

# %%
culturalspaces
# Out:
#                                                  Name  \
# 0                                          Tmrw Party
# 1                            Urban Wilderness Project
# 2                                     Bootstrap Music
# 3                                     Temple of Cairo
# 4                               Dynamic Sound Service
# ...                                               ...
# 1209                Seattle Center EMP and Sky Church
# 1210                                 The Project Room
# 1211                           Seattle Pottery Supply
# 1212                           South Side Dance Force
# 1213  University of Washington Jacob Lawrence Gallery
#
#                   neighborhood                   dominantdiscipline  \
# 0                          NaN                            Multi-use
# 1                          NaN                            Multi-use
# 2                          NaN                              Studios
# ...

# %% [markdown]
# Test: Trying to remove any extra spaces:
# byeSpaces= lambda COLUMN:COLUMN.str.strip()
#
# DF.apply(byeSpaces)
# DF['country']=DF.country.str.strip()

# %% [markdown]
# CStest['zipcode']=CStest.zipcode.str.strip()

# %% [markdown]
# Removing spaces from key attribute (zipcode)

# %%
culturalspaces['zipcode']=culturalspaces.zipcode.str.strip()

# %%
culturalspaces
# Out:
#                                                  Name  \
# 0                                          Tmrw Party
# 1                            Urban Wilderness Project
# 2                                     Bootstrap Music
# 3                                     Temple of Cairo
# 4                               Dynamic Sound Service
# ...                                               ...
# 1209                Seattle Center EMP and Sky Church
# 1210                                 The Project Room
# 1211                           Seattle Pottery Supply
# 1212                           South Side Dance Force
# 1213  University of Washington Jacob Lawrence Gallery
#
#                   neighborhood                   dominantdiscipline  \
# 0                          NaN                            Multi-use
# 1                          NaN                            Multi-use
# 2                          NaN                              Studios
# ...

# %% [markdown]
# Verifying level names are consistent:
# DF.freedomintheworld.value_counts()

# %%
culturalspaces.zipcode.value_counts()
# Out:
# 98122    93
# 98104    88
# 98103    80
# 98105    65
# 98109    55
#          ..
# 22608     1
# 14500     1
# 10510     1
# 16120     1
# 28728     1
# Name: zipcode, Length: 242, dtype: int64

# %% [markdown]
# Need to remove incorrect zip codes (i.e., only ones that start with 98- are in Seattle)

# %% [markdown]
# Testing dropping NaN zip code rows:
# df = df[df['EPS'].notna()]

# %%
CStest = CStest[CStest['zipcode'].notna()]

# %%
CStest
# Out:
#                                                  Name  \
# 3                                     Temple of Cairo
# 5                                        Keys on Main
# 6                                        Canlis Glass
# 7                         Green Lake Community Center
# 8                  Seattle Metropolitan Police Museum
# ...                                               ...
# 1209                Seattle Center EMP and Sky Church
# 1210                                 The Project Room
# 1211                           Seattle Pottery Supply
# 1212                           South Side Dance Force
# 1213  University of Washington Jacob Lawrence Gallery
#
#                   neighborhood                   dominantdiscipline  \
# 3                          NaN                       Service/Supply
# 5                          NaN                                Music
# 6                       Uptown                               Visual
# ...

# %% [markdown]
# Actually dropping rows where zip code is NA:

# %%
culturalspaces = culturalspaces[culturalspaces['zipcode'].notna()]

# %%
culturalspaces
# Out:
#                                                  Name  \
# 3                                     Temple of Cairo
# 5                                        Keys on Main
# 6                                        Canlis Glass
# 7                         Green Lake Community Center
# 8                  Seattle Metropolitan Police Museum
# ...                                               ...
# 1209                Seattle Center EMP and Sky Church
# 1210                                 The Project Room
# 1211                           Seattle Pottery Supply
# 1212                           South Side Dance Force
# 1213  University of Washington Jacob Lawrence Gallery
#
#                   neighborhood                   dominantdiscipline  \
# 3                          NaN                       Service/Supply
# 5                          NaN                                Music
# 6                       Uptown                               Visual
# ...

# %% [markdown]
# Testing dropping rows where zipcode outside of Seattle:
#
# df.drop(df[df['Age'] < 25].index, inplace = True) OR
#
# indexNames = dfObj[ (dfObj['Age'] >= 30) & (dfObj['Age'] <= 40) ].index
# dfObj.drop(indexNames , inplace=True)

# %% [markdown]
# CStest.drop(CStest[CStest['zipcode'] < 98000].index, inplace = True)

# %%
culturalspaces.dtypes
# Out:
# Name                   object
# neighborhood           object
# dominantdiscipline     object
# yearofoccupation      float64
# closeddate             object
# closed?               float64
# address                object
# zipcode                object
# dtype: object

# %% [markdown]
# QUESTION - how eliminate rows with zipcodes outside of Seattle? (i.e., zipcodes that don't start with 98?) Did above code not work because zipcode type is an object?
# Also - remove rows where closed date is NOT NA

# %% [markdown]
# For column to be used as a key, every value must be unique. If each value of key column is not unique, can't merge - must aggregate instead.

# %% [markdown]
# result - save to csv

# %% [markdown]
# Attempting to remove closed CSes
#
# racewa=racewa[racewa["Area Name"]!='Washington']

# %%
CStest=CStest[CStest["closeddate"]!='Nan']

# %%
CStest
# Out:
#                                                  Name  \
# 3                                     Temple of Cairo
# 5                                        Keys on Main
# 6                                        Canlis Glass
# 7                         Green Lake Community Center
# 8                  Seattle Metropolitan Police Museum
# ...                                               ...
# 1209                Seattle Center EMP and Sky Church
# 1210                                 The Project Room
# 1211                           Seattle Pottery Supply
# 1212                           South Side Dance Force
# 1213  University of Washington Jacob Lawrence Gallery
#
#                   neighborhood                   dominantdiscipline  \
# 3                          NaN                       Service/Supply
# 5                          NaN                                Music
# 6                       Uptown                               Visual
# ...

# %% [markdown]
# Actually removing closed spaces

# %%
culturalspaces=culturalspaces[culturalspaces["closeddate"]!='Nan']

# %%
culturalspaces
# Out:
#                                                  Name  \
# 3                                     Temple of Cairo
# 5                                        Keys on Main
# 6                                        Canlis Glass
# 7                         Green Lake Community Center
# 8                  Seattle Metropolitan Police Museum
# ...                                               ...
# 1209                Seattle Center EMP and Sky Church
# 1210                                 The Project Room
# 1211                           Seattle Pottery Supply
# 1212                           South Side Dance Force
# 1213  University of Washington Jacob Lawrence Gallery
#
#                   neighborhood                   dominantdiscipline  \
# 3                          NaN                       Service/Supply
# 5                          NaN                                Music
# 6                       Uptown                               Visual
# ...

# %% [markdown]
# # Aggregating

# %% [markdown]
# testing aggregating
#
# racewa=racewa.groupby(['Area Name','Area ID','Year']).sum()
# racewa

# %%
CStest=CStest.groupby(['zipcode']).sum()

# %%
CStest
# Out:
#          yearofoccupation  closed?
# zipcode
# 10006                 0.0      0.0
# 10015              2012.0      0.0
# 10020              2001.0      0.0
# 10105              2003.0      0.0
# 10201              1992.0      0.0
# ...                   ...      ...
# 98195             11865.0      0.0
# 98198              3896.0      0.0
# 98199              7931.0      0.0
# 98288              4025.0      0.0
# 98424              2008.0      0.0
#
# [242 rows x 2 columns]

# %%
CStest=CStest.groupby(['zipcode']).count()

# %%
CStest
# Out:
#          yearofoccupation  closed?
# zipcode
# 10006                   1        1
# 10015                   1        1
# 10020                   1        1
# 10105                   1        1
# 10201                   1        1
# ...                   ...      ...
# 98195                   1        1
# 98198                   1        1
# 98199                   1        1
# 98288                   1        1
# 98424                   1        1
#
# [242 rows x 2 columns]

# %%
CStest2=culturalspaces.copy()

# %%
CStest3=culturalspaces.copy()

# %% [markdown]
# df.groupby(['year_of_award']).agg({'award': 'count'}).rename(columns={'count': 'number_of_rows'})
#
# unique_counties = df.groupby('STNAME')['COUNTY'].nunique()

# %% [markdown]
# CStest2 = CStest2.groupby('zipcode')['address'].nunique()

# %%
CStest3 = CStest3.groupby('zipcode')['address'].nunique()

# %%
CStest3
# Out:
# zipcode
# 10006     1
# 10015     1
# 10020     1
# 10105     1
# 10201     1
#          ..
# 98195    15
# 98198     3
# 98199     8
# 98288     2
# 98424     1
# Name: address, Length: 242, dtype: int64

# %%
CStest3=pd.DataFrame(CStest3, index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-e70ad93c8977> in <module>
# ----> 1 CStest3=pd.DataFrame(CStest3, index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     461                 return
#     462
# --> 463             mgr = self._init_mgr(
#     464                 data, axes=dict(index=index, columns=columns), dtype=dtype, copy=copy
#     465             )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _init_mgr(cls, mgr, axes, dtype, copy)
#     215         for a, axe in axes.items():
#     216             if axe is not None:
# --> 217                 axe = ensure_index(axe)
#     218                 bm_axis = cls._get_block_manager_axis(a)
#     219                 mgr = mgr.reindex_axis(axe, axis=bm_axis, copy=False)
#
# ...

# %%
CStest3
# Out:
#          zipcode  culturalspaces
# zipcode
# 10006        NaN             NaN
# 10015        NaN             NaN
# 10020        NaN             NaN
# 10105        NaN             NaN
# 10201        NaN             NaN
# ...          ...             ...
# 98195        NaN             NaN
# 98198        NaN             NaN
# 98199        NaN             NaN
# 98288        NaN             NaN
# 98424        NaN             NaN
#
# [242 rows x 2 columns]

# %%
CStest3.columns=['zipcode','culturalspaces']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-9b71815331ae> in <module>
# ----> 1 CStest3.columns=['zipcode','culturalspaces']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ...

# %%
CStest3.dtypes
# Out:
# address    int64
# dtype: object

# %%
CStest4=culturalspaces.copy()

# %%
CStest4 = CStest4.groupby('zipcode')['address'].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-141-0d05a2107853> in <module>
# ----> 1 CStest4 = CStest4.groupby('zipcode')['address'].nunique()
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     226         else:
#     227             if key not in self.obj:
# --> 228                 raise KeyError(f"Column not found: {key}")
#     229             return self._gotitem(key, ndim=1)
#     230
#
# KeyError: 'Column not found: address'

# %% [markdown]
# Removing hyphens from zipcodes

# %%
CStest4
# Out:
# zipcode
# 10006     1
# 10015     1
# 10020     1
# 10105     1
# 10201     1
#          ..
# 98195    15
# 98198     3
# 98199     8
# 98288     2
# 98424     1
# Name: address, Length: 242, dtype: int64

# %%
CStest4.replace("-","")
# Out:
# zipcode
# 10006     1
# 10015     1
# 10020     1
# 10105     1
# 10201     1
#          ..
# 98195    15
# 98198     3
# 98199     8
# 98288     2
# 98424     1
# Name: address, Length: 242, dtype: int64

# %%
TestDF=pd.DataFrame(CStest4, index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-7a30081a1a97> in <module>
# ----> 1 TestDF=pd.DataFrame(CStest4, index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     493                 mgr = init_dict(data, index, columns, dtype=dtype)
#     494             elif getattr(data, "name", None) is not None:
# --> 495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
#     497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# ...

# %% [raw]
# CStest4.to_excel(r'C:\Users\elste_000\Documents\exportCStest.xlsx')

# %%
aggregatedCSexcel='https://github.com/elstephens1216/PUBPOL542/blob/main/Aggregated%20CS%20by%20zipcode.xlsx?raw=true'

# %%
aggregatedCS=pd.read_excel(aggregatedCSexcel)

# %%
aggregatedCS
# Out:
#     zipcode  address
# 0     10006        1
# 1     10015        1
# 2     10020        1
# 3     10105        1
# 4     10201        1
# ..      ...      ...
# 237   98195       15
# 238   98198        3
# 239   98199        8
# 240   98288        2
# 241   98424        1
#
# [242 rows x 2 columns]

# %%
aggregatedCS.columns=['zipcode', 'culturalspaces']

# %%
aggregatedCS
# Out:
#     zipcode  culturalspaces
# 0     10006               1
# 1     10015               1
# 2     10020               1
# 3     10105               1
# 4     10201               1
# ..      ...             ...
# 237   98195              15
# 238   98198               3
# 239   98199               8
# 240   98288               2
# 241   98424               1
#
# [242 rows x 2 columns]

# %%
aggregatedCS.to_excel(r'C:\Users\elste_000\Documents\AggregatedCulturalSpacesData.xlsx')

# %% [markdown]
# Still to do: remove zipcodes that don't start with 98

# %%
CStest3
# Out:
#          zipcode  culturalspaces
# zipcode
# 10006        NaN             NaN
# 10015        NaN             NaN
# 10020        NaN             NaN
# 10105        NaN             NaN
# 10201        NaN             NaN
# ...          ...             ...
# 98195        NaN             NaN
# 98198        NaN             NaN
# 98199        NaN             NaN
# 98288        NaN             NaN
# 98424        NaN             NaN
#
# [242 rows x 2 columns]

# %%
CStest4
# Out:
# zipcode
# 10006     1
# 10015     1
# 10020     1
# 10105     1
# 10201     1
#          ..
# 98195    15
# 98198     3
# 98199     8
# 98288     2
# 98424     1
# Name: address, Length: 242, dtype: int64

# %%
CStest4.dtype
# Out:
# dtype('int64')

# %%
CStest4.drop(CStest4[CStest4['zipcode'] < 98000].index, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'zipcode'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-227979363863> in <module>
# ...

# %%
aggregatedCS
# Out:
#     zipcode  culturalspaces
# 0     10006               1
# 1     10015               1
# 2     10020               1
# 3     10105               1
# 4     10201               1
# ..      ...             ...
# 237   98195              15
# 238   98198               3
# 239   98199               8
# 240   98288               2
# 241   98424               1
#
# [242 rows x 2 columns]

# %%
aggregatedCS.drop(aggregatedCS[aggregatedCS['zipcode'] < 98000].index, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-15bad443eff2> in <module>
# ----> 1 aggregatedCS.drop(aggregatedCS[aggregatedCS['zipcode'] < 98000].index, inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     242
# ...

# %%
aggregatedCS.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-f7808eba7bec> in <module>
# ----> 1 aggregatedCS.dtype
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
aggregatedCS.zipcode.dtype
# Out:
# dtype('O')

# %%
aggregatedCS.info
# Out:
# <bound method DataFrame.info of     zipcode  culturalspaces
# 0     10006               1
# 1     10015               1
# 2     10020               1
# 3     10105               1
# 4     10201               1
# ..      ...             ...
# 237   98195              15
# 238   98198               3
# 239   98199               8
# 240   98288               2
# 241   98424               1
#
# [242 rows x 2 columns]>

# %%
aggregatedCS.zipcode.str.startswith('98')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 237     True
# 238     True
# 239     True
# 240     True
# 241     True
# Name: zipcode, Length: 242, dtype: bool

# %%
aggregatedCS['inSeattle']=aggregatedCS.zipcode.str.startswith('98')

# %%
aggregatedCS
# Out:
#     zipcode  culturalspaces  inSeattle
# 0     10006               1      False
# 1     10015               1      False
# 2     10020               1      False
# 3     10105               1      False
# 4     10201               1      False
# ..      ...             ...        ...
# 237   98195              15       True
# 238   98198               3       True
# 239   98199               8       True
# 240   98288               2       True
# 241   98424               1       True
#
# [242 rows x 3 columns]

# %%
seattleZips=aggregatedCS[aggregatedCS.inSeattle==True]

# %%
seattleZips
# Out:
#     zipcode  culturalspaces  inSeattle
# 160   98001               1       True
# 161  98001-               1       True
# 162   98002               8       True
# 163   98003               3       True
# 164   98004               7       True
# ..      ...             ...        ...
# 237   98195              15       True
# 238   98198               3       True
# 239   98199               8       True
# 240   98288               2       True
# 241   98424               1       True
#
# [82 rows x 3 columns]

# %%
seattleZips.replace("-","")
# Out:
#     zipcode  culturalspaces  inSeattle
# 160   98001               1       True
# 161  98001-               1       True
# 162   98002               8       True
# 163   98003               3       True
# 164   98004               7       True
# ..      ...             ...        ...
# 237   98195              15       True
# 238   98198               3       True
# 239   98199               8       True
# 240   98288               2       True
# 241   98424               1       True
#
# [82 rows x 3 columns]

# %%
seattleZips.to_excel(r'C:\Users\elste_000\Documents\seattleZips.xlsx')

# %%
CStest4
# Out:
# zipcode
# 10006     1
# 10015     1
# 10020     1
# 10105     1
# 10201     1
#          ..
# 98195    15
# 98198     3
# 98199     8
# 98288     2
# 98424     1
# Name: address, Length: 242, dtype: int64

# %%
CStest5=CStest4.copy()

# %%
CStest5 = CStest5.groupby('zipcode').nunique()

# %%
CStest5
# Out:
# zipcode
# 10006    1
# 10015    1
# 10020    1
# 10105    1
# 10201    1
#         ..
# 98195    1
# 98198    1
# 98199    1
# 98288    1
# 98424    1
# Name: address, Length: 242, dtype: int64

# %%
CStest5.zipcode = CStest5.zipcode.astype(str)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-952195088b85> in <module>
# ----> 1 CStest5.zipcode = CStest5.zipcode.astype(str)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'zipcode'

# %%
DFtesting=CStest5.copy()

# %%
DFtest2=pd.DataFrame(DFtesting)

# %%
DFtest2
# Out:
#          address
# zipcode
# 10006          1
# 10015          1
# 10020          1
# 10105          1
# 10201          1
# ...          ...
# 98195          1
# 98198          1
# 98199          1
# 98288          1
# 98424          1
#
# [242 rows x 1 columns]

# %%
DFtesting
# Out:
# zipcode
# 10006    1
# 10015    1
# 10020    1
# 10105    1
# 10201    1
#         ..
# 98195    1
# 98198    1
# 98199    1
# 98288    1
# 98424    1
# Name: address, Length: 242, dtype: int64

# %%
CStest4
# Out:
# zipcode
# 10006     1
# 10015     1
# 10020     1
# 10105     1
# 10201     1
#          ..
# 98195    15
# 98198     3
# 98199     8
# 98288     2
# 98424     1
# Name: address, Length: 242, dtype: int64

# %%
seattleZips.to_excel(r'C:\Users\elste_000\Documents\seattleZips.xlsx')

# %%
CStest4.to_excel(r'C:\Users\elste_000\Documents\aggregatedzips.xlsx')

# %% [markdown]
# # Removing non-Seattle zips (final)

# %%
aggregatedzipsexcel='https://github.com/elstephens1216/PUBPOL542/blob/main/aggregatedzips.xlsx?raw=true'

# %%
AZ=pd.read_excel(aggregatedzipsexcel)

# %%
AZ
# Out:
#     zipcode  address
# 0     10006        1
# 1     10015        1
# 2     10020        1
# 3     10105        1
# 4     10201        1
# ..      ...      ...
# 230   98195       15
# 231   98198        3
# 232   98199        8
# 233   98288        2
# 234   98424        1
#
# [235 rows x 2 columns]

# %%
AZ.info
# Out:
# <bound method DataFrame.info of     zipcode  address
# 0     10006        1
# 1     10015        1
# 2     10020        1
# 3     10105        1
# 4     10201        1
# ..      ...      ...
# 230   98195       15
# 231   98198        3
# 232   98199        8
# 233   98288        2
# 234   98424        1
#
# [235 rows x 2 columns]>

# %%
AZ.zipcode.str.startswith('98')
AZ['inSeattle']=AZ.zipcode.str.startswith('98')
AZ
# Out:
#     zipcode  address inSeattle
# 0     10006        1     False
# 1     10015        1     False
# 2     10020        1     False
# 3     10105        1     False
# 4     10201        1     False
# ..      ...      ...       ...
# 230   98195       15      True
# 231   98198        3      True
# 232   98199        8      True
# 233   98288        2      True
# 234   98424        1      True
#
# [235 rows x 3 columns]

# %%
AZ=AZ[AZ.inSeattle==True]

# %%
AZ
# Out:
#     zipcode  address inSeattle
# 160   98001        2      True
# 161   98002        8      True
# 162   98003        3      True
# 163   98004        7      True
# 164   98005        2      True
# ..      ...      ...       ...
# 230   98195       15      True
# 231   98198        3      True
# 232   98199        8      True
# 233   98288        2      True
# 234   98424        1      True
#
# [74 rows x 3 columns]

# %%
del AZ['inSeattle']

# %%
AZ
# Out:
#     zipcode  address
# 160   98001        2
# 161   98002        8
# 162   98003        3
# 163   98004        7
# 164   98005        2
# ..      ...      ...
# 230   98195       15
# 231   98198        3
# 232   98199        8
# 233   98288        2
# 234   98424        1
#
# [74 rows x 2 columns]

# %%
AZ.columns=['zipcode', 'culturalspaces']

# %%
AZ
# Out:
#     zipcode  culturalspaces
# 160   98001               2
# 161   98002               8
# 162   98003               3
# 163   98004               7
# 164   98005               2
# ..      ...             ...
# 230   98195              15
# 231   98198               3
# 232   98199               8
# 233   98288               2
# 234   98424               1
#
# [74 rows x 2 columns]

# %%
AZ.to_excel(r'C:\Users\elste_000\Documents\SeattleAggregatedCulturalSpaces.xlsx')

# %%
seattleZips
# Out:
#     zipcode  culturalspaces  inSeattle
# 160   98001               1       True
# 161  98001-               1       True
# 162   98002               8       True
# 163   98003               3       True
# 164   98004               7       True
# ..      ...             ...        ...
# 237   98195              15       True
# 238   98198               3       True
# 239   98199               8       True
# 240   98288               2       True
# 241   98424               1       True
#
# [82 rows x 3 columns]

# %%
seattleZips.replace('\W',"",regex=True,inplace=True)
# Out:
# C:\Users\elste_000\anaconda3\lib\site-packages\pandas\core\frame.py:4379: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
seattleZips.zipcode.str.startswith('981')
seattleZips['inSeattle']=seattleZips.zipcode.str.startswith('981')
# Out:
# <ipython-input-182-acb3cc184cdf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seattleZips['inSeattle']=seattleZips.zipcode.str.startswith('981')

# %%
seattleZips
# Out:
#     zipcode  culturalspaces  inSeattle
# 204   98101              54       True
# 205   98101               1       True
# 206   98102              20       True
# 207   98103              77       True
# 208   98104              87       True
# 209   98105              64       True
# 210   98106               8       True
# 211   98107              35       True
# 212   98108              36       True
# 213   98109              48       True
# 214   98112              16       True
# 215   98115              27       True
# 216   98116              19       True
# 217   98116               1       True
# 218   98117              11       True
# 219   98118              35       True
# 220   98119              18       True
# 221   98121              38       True
# 222   98122              88       True
# 223   98125               4       True
# 224   98126               9       True
# 225   98133               4       True
# 226   98134              23       True
# ...

# %%
seattleZips=seattleZips[seattleZips.inSeattle==True]

# %%
seattleZips
# Out:
#     zipcode  culturalspaces  inSeattle
# 204   98101              54       True
# 205   98101               1       True
# 206   98102              20       True
# 207   98103              77       True
# 208   98104              87       True
# 209   98105              64       True
# 210   98106               8       True
# 211   98107              35       True
# 212   98108              36       True
# 213   98109              48       True
# 214   98112              16       True
# 215   98115              27       True
# 216   98116              19       True
# 217   98116               1       True
# 218   98117              11       True
# 219   98118              35       True
# 220   98119              18       True
# 221   98121              38       True
# 222   98122              88       True
# 223   98125               4       True
# 224   98126               9       True
# 225   98133               4       True
# 226   98134              23       True
# ...
